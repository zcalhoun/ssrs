# %%
import os
import shutil
import matplotlib.pyplot as plt
from PIL import Image
from natsort import natsorted

# %%
images_path = "/scratch/saad/1000_images/"
masks_path = "/scratch/saad/1000_masks/"

images_val_path = "/scratch/saad/1000_val_images/"
masks_val_path = "/scratch/saad/1000_val_masks/"

# %%
images = natsorted(os.listdir(images_path))
masks = natsorted(os.listdir(masks_path))

# %%
i = 87
img = Image.open(images_path+images[i])
mask = Image.open(masks_path+images[i])
plt.imshow(img)
plt.imshow(mask, alpha=0.5)
print(images[i])
# Out:
# austin18_11_03.tif

# %%
from src.datasets import load

train, test = load('building')
# Out:
# Normalizing using the data.
# Normalizing using the data.

# %%
for elem in train:
    if(elem[1].sum().item() != 0):
        print('yee')

# %%
train[0][0][0]
# Out:
# tensor([[-0.8883, -1.0249, -0.7322,  ...,  0.8091,  0.6140,  0.5945],
#         [-0.9273, -0.9859, -0.3810,  ...,  0.7506,  0.5750,  0.7311],
#         [-0.9663, -1.0639, -0.7908,  ...,  0.5555,  0.7115,  0.7506],
#         ...,
#         [-0.4396, -0.0689, -0.0299,  ...,  1.3164,  0.9847,  1.0822],
#         [ 0.2433,  0.1067, -0.4591,  ...,  1.1213,  1.5895,  1.1017],
#         [-0.0103,  0.0482,  0.0872,  ...,  1.1798,  1.1798,  1.0042]])
